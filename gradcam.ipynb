# %%
import tensorflow as tf
sess=tf.Session()    
saver = tf.train.import_meta_graph('./model/final_model.meta')

# %%
saver.restore(sess,tf.train.latest_checkpoint('./model'))
# Out:
# INFO:tensorflow:Restoring parameters from ./model\final_model

# %%
graph = tf.get_default_graph()

# %%
for op in graph.get_operations():
    print(op.name)
# Out:
# Variable/initial_value
# Variable
# Variable/Assign
# Variable/read
# ExponentialDecay/learning_rate
# ExponentialDecay/Cast
# ExponentialDecay/Cast_1/x
# ExponentialDecay/Cast_1
# ExponentialDecay/Cast_2/x
# ExponentialDecay/truediv
# ExponentialDecay/Floor
# ExponentialDecay/Pow
# ExponentialDecay
# Placeholder
# X
# Y
# conv1/kernel/Initializer/random_uniform/shape
# conv1/kernel/Initializer/random_uniform/min
# conv1/kernel/Initializer/random_uniform/max
# conv1/kernel/Initializer/random_uniform/RandomUniform
# conv1/kernel/Initializer/random_uniform/sub
# conv1/kernel/Initializer/random_uniform/mul
# conv1/kernel/Initializer/random_uniform
# conv1/kernel
# conv1/kernel/Assign
# conv1/kernel/read
# conv1/bias/Initializer/zeros
# conv1/bias
# conv1/bias/Assign
# conv1/bias/read
# conv1/dilation_rate
# conv1/Conv2D
# conv1/BiasAdd
# conv1/Relu
# pool1/MaxPool
# dropout/cond/Switch
# dropout/cond/switch_t
# dropout/cond/switch_f
# dropout/cond/pred_id
# dropout/cond/dropout/keep_prob
# dropout/cond/dropout/Shape/Switch
# dropout/cond/dropout/Shape
# dropout/cond/dropout/random_uniform/min
# dropout/cond/dropout/random_uniform/max
# dropout/cond/dropout/random_uniform/RandomUniform
# dropout/cond/dropout/random_uniform/sub
# dropout/cond/dropout/random_uniform/mul
# dropout/cond/dropout/random_uniform
# dropout/cond/dropout/add
# dropout/cond/dropout/Floor
# dropout/cond/dropout/div
# dropout/cond/dropout/mul
# dropout/cond/Identity/Switch
# dropout/cond/Identity
# dropout/cond/Merge
# conv2/kernel/Initializer/random_uniform/shape
# conv2/kernel/Initializer/random_uniform/min
# conv2/kernel/Initializer/random_uniform/max
# conv2/kernel/Initializer/random_uniform/RandomUniform
# conv2/kernel/Initializer/random_uniform/sub
# conv2/kernel/Initializer/random_uniform/mul
# conv2/kernel/Initializer/random_uniform
# conv2/kernel
# conv2/kernel/Assign
# conv2/kernel/read
# conv2/bias/Initializer/zeros
# conv2/bias
# conv2/bias/Assign
# conv2/bias/read
# conv2/dilation_rate
# conv2/Conv2D
# conv2/BiasAdd
# conv2/Relu
# pool2/MaxPool
# dropout_1/cond/Switch
# dropout_1/cond/switch_t
# dropout_1/cond/switch_f
# dropout_1/cond/pred_id
# dropout_1/cond/dropout/keep_prob
# dropout_1/cond/dropout/Shape/Switch
# dropout_1/cond/dropout/Shape
# dropout_1/cond/dropout/random_uniform/min
# dropout_1/cond/dropout/random_uniform/max
# dropout_1/cond/dropout/random_uniform/RandomUniform
# dropout_1/cond/dropout/random_uniform/sub
# dropout_1/cond/dropout/random_uniform/mul
# dropout_1/cond/dropout/random_uniform
# dropout_1/cond/dropout/add
# dropout_1/cond/dropout/Floor
# dropout_1/cond/dropout/div
# dropout_1/cond/dropout/mul
# dropout_1/cond/Identity/Switch
# dropout_1/cond/Identity
# dropout_1/cond/Merge
# conv3/kernel/Initializer/random_uniform/shape
# conv3/kernel/Initializer/random_uniform/min
# conv3/kernel/Initializer/random_uniform/max
# conv3/kernel/Initializer/random_uniform/RandomUniform
# conv3/kernel/Initializer/random_uniform/sub
# conv3/kernel/Initializer/random_uniform/mul
# conv3/kernel/Initializer/random_uniform
# conv3/kernel
# conv3/kernel/Assign
# conv3/kernel/read
# conv3/bias/Initializer/zeros
# conv3/bias
# conv3/bias/Assign
# conv3/bias/read
# conv3/dilation_rate
# conv3/Conv2D
# conv3/BiasAdd
# conv3/Relu
# pool3/MaxPool
# dropout_2/cond/Switch
# dropout_2/cond/switch_t
# dropout_2/cond/switch_f
# dropout_2/cond/pred_id
# dropout_2/cond/dropout/keep_prob
# dropout_2/cond/dropout/Shape/Switch
# dropout_2/cond/dropout/Shape
# dropout_2/cond/dropout/random_uniform/min
# dropout_2/cond/dropout/random_uniform/max
# dropout_2/cond/dropout/random_uniform/RandomUniform
# dropout_2/cond/dropout/random_uniform/sub
# dropout_2/cond/dropout/random_uniform/mul
# dropout_2/cond/dropout/random_uniform
# dropout_2/cond/dropout/add
# dropout_2/cond/dropout/Floor
# dropout_2/cond/dropout/div
# dropout_2/cond/dropout/mul
# dropout_2/cond/Identity/Switch
# dropout_2/cond/Identity
# dropout_2/cond/Merge
# conv4/kernel/Initializer/random_uniform/shape
# conv4/kernel/Initializer/random_uniform/min
# conv4/kernel/Initializer/random_uniform/max
# conv4/kernel/Initializer/random_uniform/RandomUniform
# conv4/kernel/Initializer/random_uniform/sub
# conv4/kernel/Initializer/random_uniform/mul
# conv4/kernel/Initializer/random_uniform
# conv4/kernel
# conv4/kernel/Assign
# conv4/kernel/read
# conv4/bias/Initializer/zeros
# conv4/bias
# conv4/bias/Assign
# conv4/bias/read
# conv4/dilation_rate
# conv4/Conv2D
# conv4/BiasAdd
# conv4/Relu
# pool4/MaxPool
# dropout_3/cond/Switch
# dropout_3/cond/switch_t
# dropout_3/cond/switch_f
# dropout_3/cond/pred_id
# dropout_3/cond/dropout/keep_prob
# dropout_3/cond/dropout/Shape/Switch
# dropout_3/cond/dropout/Shape
# dropout_3/cond/dropout/random_uniform/min
# dropout_3/cond/dropout/random_uniform/max
# dropout_3/cond/dropout/random_uniform/RandomUniform
# dropout_3/cond/dropout/random_uniform/sub
# dropout_3/cond/dropout/random_uniform/mul
# dropout_3/cond/dropout/random_uniform
# dropout_3/cond/dropout/add
# dropout_3/cond/dropout/Floor
# dropout_3/cond/dropout/div
# dropout_3/cond/dropout/mul
# dropout_3/cond/Identity/Switch
# dropout_3/cond/Identity
# dropout_3/cond/Merge
# Reshape/shape
# Reshape
# dense5/kernel/Initializer/random_uniform/shape
# dense5/kernel/Initializer/random_uniform/min
# dense5/kernel/Initializer/random_uniform/max
# dense5/kernel/Initializer/random_uniform/RandomUniform
# dense5/kernel/Initializer/random_uniform/sub
# dense5/kernel/Initializer/random_uniform/mul
# dense5/kernel/Initializer/random_uniform
# dense5/kernel
# dense5/kernel/Assign
# dense5/kernel/read
# dense5/bias/Initializer/zeros
# dense5/bias
# dense5/bias/Assign
# dense5/bias/read
# dense5/MatMul
# dense5/BiasAdd
# dense5/Relu
# dropout_4/cond/Switch
# dropout_4/cond/switch_t
# dropout_4/cond/switch_f
# dropout_4/cond/pred_id
# dropout_4/cond/dropout/keep_prob
# dropout_4/cond/dropout/Shape/Switch
# dropout_4/cond/dropout/Shape
# dropout_4/cond/dropout/random_uniform/min
# dropout_4/cond/dropout/random_uniform/max
# dropout_4/cond/dropout/random_uniform/RandomUniform
# dropout_4/cond/dropout/random_uniform/sub
# dropout_4/cond/dropout/random_uniform/mul
# dropout_4/cond/dropout/random_uniform
# dropout_4/cond/dropout/add
# dropout_4/cond/dropout/Floor
# dropout_4/cond/dropout/div
# dropout_4/cond/dropout/mul
# dropout_4/cond/Identity/Switch
# dropout_4/cond/Identity
# dropout_4/cond/Merge
# logits/kernel/Initializer/random_uniform/shape
# logits/kernel/Initializer/random_uniform/min
# logits/kernel/Initializer/random_uniform/max
# logits/kernel/Initializer/random_uniform/RandomUniform
# logits/kernel/Initializer/random_uniform/sub
# logits/kernel/Initializer/random_uniform/mul
# logits/kernel/Initializer/random_uniform
# logits/kernel
# logits/kernel/Assign
# logits/kernel/read
# logits/bias/Initializer/zeros
# logits/bias
# logits/bias/Assign
# logits/bias/read
# logits/MatMul
# logits/BiasAdd
# softmax_cross_entropy_with_logits_sg/labels_stop_gradient
# softmax_cross_entropy_with_logits_sg/Rank
# softmax_cross_entropy_with_logits_sg/Shape
# softmax_cross_entropy_with_logits_sg/Rank_1
# softmax_cross_entropy_with_logits_sg/Shape_1
# softmax_cross_entropy_with_logits_sg/Sub/y
# softmax_cross_entropy_with_logits_sg/Sub
# softmax_cross_entropy_with_logits_sg/Slice/begin
# softmax_cross_entropy_with_logits_sg/Slice/size
# softmax_cross_entropy_with_logits_sg/Slice
# softmax_cross_entropy_with_logits_sg/concat/values_0
# softmax_cross_entropy_with_logits_sg/concat/axis
# softmax_cross_entropy_with_logits_sg/concat
# softmax_cross_entropy_with_logits_sg/Reshape
# softmax_cross_entropy_with_logits_sg/Rank_2
# softmax_cross_entropy_with_logits_sg/Shape_2
# softmax_cross_entropy_with_logits_sg/Sub_1/y
# softmax_cross_entropy_with_logits_sg/Sub_1
# softmax_cross_entropy_with_logits_sg/Slice_1/begin
# softmax_cross_entropy_with_logits_sg/Slice_1/size
# softmax_cross_entropy_with_logits_sg/Slice_1
# softmax_cross_entropy_with_logits_sg/concat_1/values_0
# softmax_cross_entropy_with_logits_sg/concat_1/axis
# softmax_cross_entropy_with_logits_sg/concat_1
# softmax_cross_entropy_with_logits_sg/Reshape_1
# softmax_cross_entropy_with_logits_sg
# softmax_cross_entropy_with_logits_sg/Sub_2/y
# softmax_cross_entropy_with_logits_sg/Sub_2
# softmax_cross_entropy_with_logits_sg/Slice_2/begin
# softmax_cross_entropy_with_logits_sg/Slice_2/size
# softmax_cross_entropy_with_logits_sg/Slice_2
# softmax_cross_entropy_with_logits_sg/Reshape_2
# Const
# cost
# gradients/Shape
# gradients/grad_ys_0
# gradients/Fill
# gradients/cost_grad/Reshape/shape
# gradients/cost_grad/Reshape
# gradients/cost_grad/Shape
# gradients/cost_grad/Tile
# gradients/cost_grad/Shape_1
# gradients/cost_grad/Shape_2
# gradients/cost_grad/Const
# gradients/cost_grad/Prod
# gradients/cost_grad/Const_1
# gradients/cost_grad/Prod_1
# gradients/cost_grad/Maximum/y
# gradients/cost_grad/Maximum
# gradients/cost_grad/floordiv
# gradients/cost_grad/Cast
# gradients/cost_grad/truediv
# gradients/softmax_cross_entropy_with_logits_sg/Reshape_2_grad/Shape
# gradients/softmax_cross_entropy_with_logits_sg/Reshape_2_grad/Reshape
# gradients/zeros_like
# gradients/softmax_cross_entropy_with_logits_sg_grad/ExpandDims/dim
# gradients/softmax_cross_entropy_with_logits_sg_grad/ExpandDims
# gradients/softmax_cross_entropy_with_logits_sg_grad/mul
# gradients/softmax_cross_entropy_with_logits_sg_grad/LogSoftmax
# gradients/softmax_cross_entropy_with_logits_sg_grad/Neg
# gradients/softmax_cross_entropy_with_logits_sg_grad/ExpandDims_1/dim
# gradients/softmax_cross_entropy_with_logits_sg_grad/ExpandDims_1
# gradients/softmax_cross_entropy_with_logits_sg_grad/mul_1
# gradients/softmax_cross_entropy_with_logits_sg_grad/tuple/group_deps
# gradients/softmax_cross_entropy_with_logits_sg_grad/tuple/control_dependency
# gradients/softmax_cross_entropy_with_logits_sg_grad/tuple/control_dependency_1
# gradients/softmax_cross_entropy_with_logits_sg/Reshape_grad/Shape
# gradients/softmax_cross_entropy_with_logits_sg/Reshape_grad/Reshape
# gradients/logits/BiasAdd_grad/BiasAddGrad
# gradients/logits/BiasAdd_grad/tuple/group_deps
# gradients/logits/BiasAdd_grad/tuple/control_dependency
# gradients/logits/BiasAdd_grad/tuple/control_dependency_1
# gradients/logits/MatMul_grad/MatMul
# gradients/logits/MatMul_grad/MatMul_1
# gradients/logits/MatMul_grad/tuple/group_deps
# gradients/logits/MatMul_grad/tuple/control_dependency
# gradients/logits/MatMul_grad/tuple/control_dependency_1
# gradients/dropout_4/cond/Merge_grad/cond_grad
# gradients/dropout_4/cond/Merge_grad/tuple/group_deps
# gradients/dropout_4/cond/Merge_grad/tuple/control_dependency
# gradients/dropout_4/cond/Merge_grad/tuple/control_dependency_1
# gradients/dropout_4/cond/dropout/mul_grad/Shape
# gradients/dropout_4/cond/dropout/mul_grad/Shape_1
# gradients/dropout_4/cond/dropout/mul_grad/BroadcastGradientArgs
# gradients/dropout_4/cond/dropout/mul_grad/Mul
# gradients/dropout_4/cond/dropout/mul_grad/Sum
# gradients/dropout_4/cond/dropout/mul_grad/Reshape
# gradients/dropout_4/cond/dropout/mul_grad/Mul_1
# gradients/dropout_4/cond/dropout/mul_grad/Sum_1
# gradients/dropout_4/cond/dropout/mul_grad/Reshape_1
# gradients/dropout_4/cond/dropout/mul_grad/tuple/group_deps
# gradients/dropout_4/cond/dropout/mul_grad/tuple/control_dependency
# gradients/dropout_4/cond/dropout/mul_grad/tuple/control_dependency_1
# gradients/Switch
# gradients/Shape_1
# gradients/zeros/Const
# gradients/zeros
# gradients/dropout_4/cond/Identity/Switch_grad/cond_grad
# gradients/dropout_4/cond/dropout/div_grad/Shape
# gradients/dropout_4/cond/dropout/div_grad/Shape_1
# gradients/dropout_4/cond/dropout/div_grad/BroadcastGradientArgs
# gradients/dropout_4/cond/dropout/div_grad/RealDiv
# gradients/dropout_4/cond/dropout/div_grad/Sum
# gradients/dropout_4/cond/dropout/div_grad/Reshape
# gradients/dropout_4/cond/dropout/div_grad/Neg
# gradients/dropout_4/cond/dropout/div_grad/RealDiv_1
# gradients/dropout_4/cond/dropout/div_grad/RealDiv_2
# gradients/dropout_4/cond/dropout/div_grad/mul
# gradients/dropout_4/cond/dropout/div_grad/Sum_1
# gradients/dropout_4/cond/dropout/div_grad/Reshape_1
# gradients/dropout_4/cond/dropout/div_grad/tuple/group_deps
# gradients/dropout_4/cond/dropout/div_grad/tuple/control_dependency
# gradients/dropout_4/cond/dropout/div_grad/tuple/control_dependency_1
# gradients/Switch_1
# gradients/Shape_2
# gradients/zeros_1/Const
# gradients/zeros_1
# gradients/dropout_4/cond/dropout/Shape/Switch_grad/cond_grad
# gradients/AddN
# gradients/dense5/Relu_grad/ReluGrad
# gradients/dense5/BiasAdd_grad/BiasAddGrad
# gradients/dense5/BiasAdd_grad/tuple/group_deps
# gradients/dense5/BiasAdd_grad/tuple/control_dependency
# gradients/dense5/BiasAdd_grad/tuple/control_dependency_1
# gradients/dense5/MatMul_grad/MatMul
# gradients/dense5/MatMul_grad/MatMul_1
# gradients/dense5/MatMul_grad/tuple/group_deps
# gradients/dense5/MatMul_grad/tuple/control_dependency
# gradients/dense5/MatMul_grad/tuple/control_dependency_1
# gradients/Reshape_grad/Shape
# gradients/Reshape_grad/Reshape
# gradients/dropout_3/cond/Merge_grad/cond_grad
# gradients/dropout_3/cond/Merge_grad/tuple/group_deps
# gradients/dropout_3/cond/Merge_grad/tuple/control_dependency
# gradients/dropout_3/cond/Merge_grad/tuple/control_dependency_1
# gradients/dropout_3/cond/dropout/mul_grad/Shape
# gradients/dropout_3/cond/dropout/mul_grad/Shape_1
# gradients/dropout_3/cond/dropout/mul_grad/BroadcastGradientArgs
# gradients/dropout_3/cond/dropout/mul_grad/Mul
# gradients/dropout_3/cond/dropout/mul_grad/Sum
# gradients/dropout_3/cond/dropout/mul_grad/Reshape
# gradients/dropout_3/cond/dropout/mul_grad/Mul_1
# gradients/dropout_3/cond/dropout/mul_grad/Sum_1
# gradients/dropout_3/cond/dropout/mul_grad/Reshape_1
# gradients/dropout_3/cond/dropout/mul_grad/tuple/group_deps
# gradients/dropout_3/cond/dropout/mul_grad/tuple/control_dependency
# gradients/dropout_3/cond/dropout/mul_grad/tuple/control_dependency_1
# gradients/Switch_2
# gradients/Shape_3
# gradients/zeros_2/Const
# gradients/zeros_2
# gradients/dropout_3/cond/Identity/Switch_grad/cond_grad
# gradients/dropout_3/cond/dropout/div_grad/Shape
# gradients/dropout_3/cond/dropout/div_grad/Shape_1
# gradients/dropout_3/cond/dropout/div_grad/BroadcastGradientArgs
# gradients/dropout_3/cond/dropout/div_grad/RealDiv
# gradients/dropout_3/cond/dropout/div_grad/Sum
# gradients/dropout_3/cond/dropout/div_grad/Reshape
# gradients/dropout_3/cond/dropout/div_grad/Neg
# gradients/dropout_3/cond/dropout/div_grad/RealDiv_1
# gradients/dropout_3/cond/dropout/div_grad/RealDiv_2
# gradients/dropout_3/cond/dropout/div_grad/mul
# gradients/dropout_3/cond/dropout/div_grad/Sum_1
# gradients/dropout_3/cond/dropout/div_grad/Reshape_1
# gradients/dropout_3/cond/dropout/div_grad/tuple/group_deps
# gradients/dropout_3/cond/dropout/div_grad/tuple/control_dependency
# gradients/dropout_3/cond/dropout/div_grad/tuple/control_dependency_1
# gradients/Switch_3
# gradients/Shape_4
# gradients/zeros_3/Const
# gradients/zeros_3
# gradients/dropout_3/cond/dropout/Shape/Switch_grad/cond_grad
# gradients/AddN_1
# gradients/pool4/MaxPool_grad/MaxPoolGrad
# gradients/conv4/Relu_grad/ReluGrad
# gradients/conv4/BiasAdd_grad/BiasAddGrad
# gradients/conv4/BiasAdd_grad/tuple/group_deps
# gradients/conv4/BiasAdd_grad/tuple/control_dependency
# gradients/conv4/BiasAdd_grad/tuple/control_dependency_1
# gradients/conv4/Conv2D_grad/ShapeN
# gradients/conv4/Conv2D_grad/Const
# gradients/conv4/Conv2D_grad/Conv2DBackpropInput
# gradients/conv4/Conv2D_grad/Conv2DBackpropFilter
# gradients/conv4/Conv2D_grad/tuple/group_deps
# gradients/conv4/Conv2D_grad/tuple/control_dependency
# gradients/conv4/Conv2D_grad/tuple/control_dependency_1
# gradients/dropout_2/cond/Merge_grad/cond_grad
# gradients/dropout_2/cond/Merge_grad/tuple/group_deps
# gradients/dropout_2/cond/Merge_grad/tuple/control_dependency
# gradients/dropout_2/cond/Merge_grad/tuple/control_dependency_1
# gradients/dropout_2/cond/dropout/mul_grad/Shape
# gradients/dropout_2/cond/dropout/mul_grad/Shape_1
# gradients/dropout_2/cond/dropout/mul_grad/BroadcastGradientArgs
# gradients/dropout_2/cond/dropout/mul_grad/Mul
# gradients/dropout_2/cond/dropout/mul_grad/Sum
# gradients/dropout_2/cond/dropout/mul_grad/Reshape
# gradients/dropout_2/cond/dropout/mul_grad/Mul_1
# gradients/dropout_2/cond/dropout/mul_grad/Sum_1
# gradients/dropout_2/cond/dropout/mul_grad/Reshape_1
# gradients/dropout_2/cond/dropout/mul_grad/tuple/group_deps
# gradients/dropout_2/cond/dropout/mul_grad/tuple/control_dependency
# gradients/dropout_2/cond/dropout/mul_grad/tuple/control_dependency_1
# gradients/Switch_4
# gradients/Shape_5
# gradients/zeros_4/Const
# gradients/zeros_4
# gradients/dropout_2/cond/Identity/Switch_grad/cond_grad
# gradients/dropout_2/cond/dropout/div_grad/Shape
# gradients/dropout_2/cond/dropout/div_grad/Shape_1
# gradients/dropout_2/cond/dropout/div_grad/BroadcastGradientArgs
# gradients/dropout_2/cond/dropout/div_grad/RealDiv
# gradients/dropout_2/cond/dropout/div_grad/Sum
# gradients/dropout_2/cond/dropout/div_grad/Reshape
# gradients/dropout_2/cond/dropout/div_grad/Neg
# gradients/dropout_2/cond/dropout/div_grad/RealDiv_1
# gradients/dropout_2/cond/dropout/div_grad/RealDiv_2
# gradients/dropout_2/cond/dropout/div_grad/mul
# gradients/dropout_2/cond/dropout/div_grad/Sum_1
# gradients/dropout_2/cond/dropout/div_grad/Reshape_1
# gradients/dropout_2/cond/dropout/div_grad/tuple/group_deps
# gradients/dropout_2/cond/dropout/div_grad/tuple/control_dependency
# gradients/dropout_2/cond/dropout/div_grad/tuple/control_dependency_1
# gradients/Switch_5
# gradients/Shape_6
# gradients/zeros_5/Const
# gradients/zeros_5
# gradients/dropout_2/cond/dropout/Shape/Switch_grad/cond_grad
# gradients/AddN_2
# gradients/pool3/MaxPool_grad/MaxPoolGrad
# gradients/conv3/Relu_grad/ReluGrad
# gradients/conv3/BiasAdd_grad/BiasAddGrad
# gradients/conv3/BiasAdd_grad/tuple/group_deps
# gradients/conv3/BiasAdd_grad/tuple/control_dependency
# gradients/conv3/BiasAdd_grad/tuple/control_dependency_1
# gradients/conv3/Conv2D_grad/ShapeN
# gradients/conv3/Conv2D_grad/Const
# gradients/conv3/Conv2D_grad/Conv2DBackpropInput
# gradients/conv3/Conv2D_grad/Conv2DBackpropFilter
# gradients/conv3/Conv2D_grad/tuple/group_deps
# gradients/conv3/Conv2D_grad/tuple/control_dependency
# gradients/conv3/Conv2D_grad/tuple/control_dependency_1
# gradients/dropout_1/cond/Merge_grad/cond_grad
# gradients/dropout_1/cond/Merge_grad/tuple/group_deps
# gradients/dropout_1/cond/Merge_grad/tuple/control_dependency
# gradients/dropout_1/cond/Merge_grad/tuple/control_dependency_1
# gradients/dropout_1/cond/dropout/mul_grad/Shape
# gradients/dropout_1/cond/dropout/mul_grad/Shape_1
# gradients/dropout_1/cond/dropout/mul_grad/BroadcastGradientArgs
# gradients/dropout_1/cond/dropout/mul_grad/Mul
# gradients/dropout_1/cond/dropout/mul_grad/Sum
# gradients/dropout_1/cond/dropout/mul_grad/Reshape
# gradients/dropout_1/cond/dropout/mul_grad/Mul_1
# gradients/dropout_1/cond/dropout/mul_grad/Sum_1
# gradients/dropout_1/cond/dropout/mul_grad/Reshape_1
# gradients/dropout_1/cond/dropout/mul_grad/tuple/group_deps
# gradients/dropout_1/cond/dropout/mul_grad/tuple/control_dependency
# gradients/dropout_1/cond/dropout/mul_grad/tuple/control_dependency_1
# gradients/Switch_6
# gradients/Shape_7
# gradients/zeros_6/Const
# gradients/zeros_6
# gradients/dropout_1/cond/Identity/Switch_grad/cond_grad
# gradients/dropout_1/cond/dropout/div_grad/Shape
# gradients/dropout_1/cond/dropout/div_grad/Shape_1
# gradients/dropout_1/cond/dropout/div_grad/BroadcastGradientArgs
# gradients/dropout_1/cond/dropout/div_grad/RealDiv
# gradients/dropout_1/cond/dropout/div_grad/Sum
# gradients/dropout_1/cond/dropout/div_grad/Reshape
# gradients/dropout_1/cond/dropout/div_grad/Neg
# gradients/dropout_1/cond/dropout/div_grad/RealDiv_1
# gradients/dropout_1/cond/dropout/div_grad/RealDiv_2
# gradients/dropout_1/cond/dropout/div_grad/mul
# gradients/dropout_1/cond/dropout/div_grad/Sum_1
# gradients/dropout_1/cond/dropout/div_grad/Reshape_1
# gradients/dropout_1/cond/dropout/div_grad/tuple/group_deps
# gradients/dropout_1/cond/dropout/div_grad/tuple/control_dependency
# gradients/dropout_1/cond/dropout/div_grad/tuple/control_dependency_1
# gradients/Switch_7
# gradients/Shape_8
# gradients/zeros_7/Const
# gradients/zeros_7
# gradients/dropout_1/cond/dropout/Shape/Switch_grad/cond_grad
# gradients/AddN_3
# gradients/pool2/MaxPool_grad/MaxPoolGrad
# gradients/conv2/Relu_grad/ReluGrad
# gradients/conv2/BiasAdd_grad/BiasAddGrad
# gradients/conv2/BiasAdd_grad/tuple/group_deps
# gradients/conv2/BiasAdd_grad/tuple/control_dependency
# gradients/conv2/BiasAdd_grad/tuple/control_dependency_1
# gradients/conv2/Conv2D_grad/ShapeN
# gradients/conv2/Conv2D_grad/Const
# gradients/conv2/Conv2D_grad/Conv2DBackpropInput
# gradients/conv2/Conv2D_grad/Conv2DBackpropFilter
# gradients/conv2/Conv2D_grad/tuple/group_deps
# gradients/conv2/Conv2D_grad/tuple/control_dependency
# gradients/conv2/Conv2D_grad/tuple/control_dependency_1
# gradients/dropout/cond/Merge_grad/cond_grad
# gradients/dropout/cond/Merge_grad/tuple/group_deps
# gradients/dropout/cond/Merge_grad/tuple/control_dependency
# gradients/dropout/cond/Merge_grad/tuple/control_dependency_1
# gradients/dropout/cond/dropout/mul_grad/Shape
# gradients/dropout/cond/dropout/mul_grad/Shape_1
# gradients/dropout/cond/dropout/mul_grad/BroadcastGradientArgs
# gradients/dropout/cond/dropout/mul_grad/Mul
# gradients/dropout/cond/dropout/mul_grad/Sum
# gradients/dropout/cond/dropout/mul_grad/Reshape
# gradients/dropout/cond/dropout/mul_grad/Mul_1
# gradients/dropout/cond/dropout/mul_grad/Sum_1
# gradients/dropout/cond/dropout/mul_grad/Reshape_1
# gradients/dropout/cond/dropout/mul_grad/tuple/group_deps
# gradients/dropout/cond/dropout/mul_grad/tuple/control_dependency
# gradients/dropout/cond/dropout/mul_grad/tuple/control_dependency_1
# gradients/Switch_8
# gradients/Shape_9
# gradients/zeros_8/Const
# gradients/zeros_8
# gradients/dropout/cond/Identity/Switch_grad/cond_grad
# gradients/dropout/cond/dropout/div_grad/Shape
# gradients/dropout/cond/dropout/div_grad/Shape_1
# gradients/dropout/cond/dropout/div_grad/BroadcastGradientArgs
# gradients/dropout/cond/dropout/div_grad/RealDiv
# gradients/dropout/cond/dropout/div_grad/Sum
# gradients/dropout/cond/dropout/div_grad/Reshape
# gradients/dropout/cond/dropout/div_grad/Neg
# gradients/dropout/cond/dropout/div_grad/RealDiv_1
# gradients/dropout/cond/dropout/div_grad/RealDiv_2
# gradients/dropout/cond/dropout/div_grad/mul
# gradients/dropout/cond/dropout/div_grad/Sum_1
# gradients/dropout/cond/dropout/div_grad/Reshape_1
# gradients/dropout/cond/dropout/div_grad/tuple/group_deps
# gradients/dropout/cond/dropout/div_grad/tuple/control_dependency
# gradients/dropout/cond/dropout/div_grad/tuple/control_dependency_1
# gradients/Switch_9
# gradients/Shape_10
# gradients/zeros_9/Const
# gradients/zeros_9
# gradients/dropout/cond/dropout/Shape/Switch_grad/cond_grad
# gradients/AddN_4
# gradients/pool1/MaxPool_grad/MaxPoolGrad
# gradients/conv1/Relu_grad/ReluGrad
# gradients/conv1/BiasAdd_grad/BiasAddGrad
# gradients/conv1/BiasAdd_grad/tuple/group_deps
# gradients/conv1/BiasAdd_grad/tuple/control_dependency
# gradients/conv1/BiasAdd_grad/tuple/control_dependency_1
# gradients/conv1/Conv2D_grad/ShapeN
# gradients/conv1/Conv2D_grad/Const
# gradients/conv1/Conv2D_grad/Conv2DBackpropInput
# gradients/conv1/Conv2D_grad/Conv2DBackpropFilter
# gradients/conv1/Conv2D_grad/tuple/group_deps
# gradients/conv1/Conv2D_grad/tuple/control_dependency
# gradients/conv1/Conv2D_grad/tuple/control_dependency_1
# beta1_power/initial_value
# beta1_power
# beta1_power/Assign
# beta1_power/read
# beta2_power/initial_value
# beta2_power
# beta2_power/Assign
# beta2_power/read
# conv1/kernel/Adam/Initializer/zeros
# conv1/kernel/Adam
# conv1/kernel/Adam/Assign
# conv1/kernel/Adam/read
# conv1/kernel/Adam_1/Initializer/zeros
# conv1/kernel/Adam_1
# conv1/kernel/Adam_1/Assign
# conv1/kernel/Adam_1/read
# conv1/bias/Adam/Initializer/zeros
# conv1/bias/Adam
# conv1/bias/Adam/Assign
# conv1/bias/Adam/read
# conv1/bias/Adam_1/Initializer/zeros
# conv1/bias/Adam_1
# conv1/bias/Adam_1/Assign
# conv1/bias/Adam_1/read
# conv2/kernel/Adam/Initializer/zeros/shape_as_tensor
# conv2/kernel/Adam/Initializer/zeros/Const
# conv2/kernel/Adam/Initializer/zeros
# conv2/kernel/Adam
# conv2/kernel/Adam/Assign
# conv2/kernel/Adam/read
# conv2/kernel/Adam_1/Initializer/zeros/shape_as_tensor
# conv2/kernel/Adam_1/Initializer/zeros/Const
# conv2/kernel/Adam_1/Initializer/zeros
# conv2/kernel/Adam_1
# conv2/kernel/Adam_1/Assign
# conv2/kernel/Adam_1/read
# conv2/bias/Adam/Initializer/zeros
# conv2/bias/Adam
# conv2/bias/Adam/Assign
# conv2/bias/Adam/read
# conv2/bias/Adam_1/Initializer/zeros
# conv2/bias/Adam_1
# conv2/bias/Adam_1/Assign
# conv2/bias/Adam_1/read
# conv3/kernel/Adam/Initializer/zeros/shape_as_tensor
# conv3/kernel/Adam/Initializer/zeros/Const
# conv3/kernel/Adam/Initializer/zeros
# conv3/kernel/Adam
# conv3/kernel/Adam/Assign
# conv3/kernel/Adam/read
# conv3/kernel/Adam_1/Initializer/zeros/shape_as_tensor
# conv3/kernel/Adam_1/Initializer/zeros/Const
# conv3/kernel/Adam_1/Initializer/zeros
# conv3/kernel/Adam_1
# conv3/kernel/Adam_1/Assign
# conv3/kernel/Adam_1/read
# conv3/bias/Adam/Initializer/zeros
# conv3/bias/Adam
# conv3/bias/Adam/Assign
# conv3/bias/Adam/read
# conv3/bias/Adam_1/Initializer/zeros
# conv3/bias/Adam_1
# conv3/bias/Adam_1/Assign
# conv3/bias/Adam_1/read
# conv4/kernel/Adam/Initializer/zeros/shape_as_tensor
# conv4/kernel/Adam/Initializer/zeros/Const
# conv4/kernel/Adam/Initializer/zeros
# conv4/kernel/Adam
# conv4/kernel/Adam/Assign
# conv4/kernel/Adam/read
# conv4/kernel/Adam_1/Initializer/zeros/shape_as_tensor
# conv4/kernel/Adam_1/Initializer/zeros/Const
# conv4/kernel/Adam_1/Initializer/zeros
# conv4/kernel/Adam_1
# conv4/kernel/Adam_1/Assign
# conv4/kernel/Adam_1/read
# conv4/bias/Adam/Initializer/zeros
# conv4/bias/Adam
# conv4/bias/Adam/Assign
# conv4/bias/Adam/read
# conv4/bias/Adam_1/Initializer/zeros
# conv4/bias/Adam_1
# conv4/bias/Adam_1/Assign
# conv4/bias/Adam_1/read
# dense5/kernel/Adam/Initializer/zeros/shape_as_tensor
# dense5/kernel/Adam/Initializer/zeros/Const
# dense5/kernel/Adam/Initializer/zeros
# dense5/kernel/Adam
# dense5/kernel/Adam/Assign
# dense5/kernel/Adam/read
# dense5/kernel/Adam_1/Initializer/zeros/shape_as_tensor
# dense5/kernel/Adam_1/Initializer/zeros/Const
# dense5/kernel/Adam_1/Initializer/zeros
# dense5/kernel/Adam_1
# dense5/kernel/Adam_1/Assign
# dense5/kernel/Adam_1/read
# dense5/bias/Adam/Initializer/zeros
# dense5/bias/Adam
# dense5/bias/Adam/Assign
# dense5/bias/Adam/read
# dense5/bias/Adam_1/Initializer/zeros
# dense5/bias/Adam_1
# dense5/bias/Adam_1/Assign
# dense5/bias/Adam_1/read
# logits/kernel/Adam/Initializer/zeros/shape_as_tensor
# logits/kernel/Adam/Initializer/zeros/Const
# logits/kernel/Adam/Initializer/zeros
# logits/kernel/Adam
# logits/kernel/Adam/Assign
# logits/kernel/Adam/read
# logits/kernel/Adam_1/Initializer/zeros/shape_as_tensor
# logits/kernel/Adam_1/Initializer/zeros/Const
# logits/kernel/Adam_1/Initializer/zeros
# logits/kernel/Adam_1
# logits/kernel/Adam_1/Assign
# logits/kernel/Adam_1/read
# logits/bias/Adam/Initializer/zeros
# logits/bias/Adam
# logits/bias/Adam/Assign
# logits/bias/Adam/read
# logits/bias/Adam_1/Initializer/zeros
# logits/bias/Adam_1
# logits/bias/Adam_1/Assign
# logits/bias/Adam_1/read
# Adam/beta1
# Adam/beta2
# Adam/epsilon
# Adam/update_conv1/kernel/ApplyAdam
# Adam/update_conv1/bias/ApplyAdam
# Adam/update_conv2/kernel/ApplyAdam
# Adam/update_conv2/bias/ApplyAdam
# Adam/update_conv3/kernel/ApplyAdam
# Adam/update_conv3/bias/ApplyAdam
# Adam/update_conv4/kernel/ApplyAdam
# Adam/update_conv4/bias/ApplyAdam
# Adam/update_dense5/kernel/ApplyAdam
# Adam/update_dense5/bias/ApplyAdam
# Adam/update_logits/kernel/ApplyAdam
# Adam/update_logits/bias/ApplyAdam
# Adam/mul
# Adam/Assign
# Adam/mul_1
# Adam/Assign_1
# Adam/update
# Adam/value
# Adam
# ArgMax/dimension
# ArgMax
# ArgMax_1/dimension
# ArgMax_1
# Equal
# Cast
# Const_1
# pred
# cost_1/tags
# cost_1
# accuracy/tags
# accuracy
# Merge/MergeSummary
# init
# save/Const
# save/SaveV2/tensor_names
# save/SaveV2/shape_and_slices
# save/SaveV2
# save/control_dependency
# save/RestoreV2/tensor_names
# save/RestoreV2/shape_and_slices
# save/RestoreV2
# save/Assign
# save/Assign_1
# save/Assign_2
# save/Assign_3
# save/Assign_4
# save/Assign_5
# save/Assign_6
# save/Assign_7
# save/Assign_8
# save/Assign_9
# save/Assign_10
# save/Assign_11
# save/Assign_12
# save/Assign_13
# save/Assign_14
# save/Assign_15
# save/Assign_16
# save/Assign_17
# save/Assign_18
# save/Assign_19
# save/Assign_20
# save/Assign_21
# save/Assign_22
# save/Assign_23
# save/Assign_24
# save/Assign_25
# save/Assign_26
# save/Assign_27
# save/Assign_28
# save/Assign_29
# save/Assign_30
# save/Assign_31
# save/Assign_32
# save/Assign_33
# save/Assign_34
# save/Assign_35
# save/Assign_36
# save/Assign_37
# save/Assign_38
# save/restore_all
# one_hot/on_value
# one_hot/off_value
# one_hot/indices
# one_hot/depth
# one_hot
# one_hot_1/on_value
# one_hot_1/off_value
# one_hot_1/indices
# one_hot_1/depth
# one_hot_1
# rgb_to_grayscale/images
# rgb_to_grayscale/convert_image/Cast
# rgb_to_grayscale/convert_image/y
# rgb_to_grayscale/convert_image
# rgb_to_grayscale/Tensordot/b
# rgb_to_grayscale/Tensordot/transpose/perm
# rgb_to_grayscale/Tensordot/transpose
# rgb_to_grayscale/Tensordot/Reshape/shape
# rgb_to_grayscale/Tensordot/Reshape
# rgb_to_grayscale/Tensordot/transpose_1/perm
# rgb_to_grayscale/Tensordot/transpose_1
# rgb_to_grayscale/Tensordot/Reshape_1/shape
# rgb_to_grayscale/Tensordot/Reshape_1
# rgb_to_grayscale/Tensordot/MatMul
# rgb_to_grayscale/Tensordot/shape
# rgb_to_grayscale/Tensordot
# rgb_to_grayscale/ExpandDims/dim
# rgb_to_grayscale/ExpandDims
# rgb_to_grayscale/Mul/y
# rgb_to_grayscale/Mul
# rgb_to_grayscale
# rgb_to_grayscale_1/images
# rgb_to_grayscale_1/convert_image/Cast
# rgb_to_grayscale_1/convert_image/y
# rgb_to_grayscale_1/convert_image
# rgb_to_grayscale_1/Tensordot/b
# rgb_to_grayscale_1/Tensordot/transpose/perm
# rgb_to_grayscale_1/Tensordot/transpose
# rgb_to_grayscale_1/Tensordot/Reshape/shape
# rgb_to_grayscale_1/Tensordot/Reshape
# rgb_to_grayscale_1/Tensordot/transpose_1/perm
# rgb_to_grayscale_1/Tensordot/transpose_1
# rgb_to_grayscale_1/Tensordot/Reshape_1/shape
# rgb_to_grayscale_1/Tensordot/Reshape_1
# rgb_to_grayscale_1/Tensordot/MatMul
# rgb_to_grayscale_1/Tensordot/shape
# rgb_to_grayscale_1/Tensordot
# rgb_to_grayscale_1/ExpandDims/dim
# rgb_to_grayscale_1/ExpandDims
# rgb_to_grayscale_1/Mul/y
# rgb_to_grayscale_1/Mul
# rgb_to_grayscale_1

# %%
xs = graph.get_tensor_by_name("conv3/Conv2D:0")
ys = graph.get_tensor_by_name("logits/BiasAdd:0")

# %%
grads = [tf.gradients(ys[0, i], xs) for i in range(10)]

# %%
X = graph.get_tensor_by_name("X:0")
Y = graph.get_tensor_by_name("Y:0")
pred = graph.get_tensor_by_name("ArgMax:0")
correct = graph.get_tensor_by_name("Equal:0")

# %%
import sys
sys.path.append('../')
import read_stl10_file

# %%
images_test = read_stl10_file.read_all_images(read_stl10_file.DATA_PATH)[0:50]
labels_test = read_stl10_file.read_labels(read_stl10_file.LABEL_PATH)[0:50] - 1
oh_ = tf.one_hot(labels_test, depth=10)
gr_ = tf.image.rgb_to_grayscale(images_test)
images_test_gray, labels_test_onehot = sess.run([gr_, oh_])

# %%
index = 10
image_sample = images_test[index,:,:,:]
image_sample_gray = images_test_gray[index,:,:,:]
label_sample = labels_test_onehot[index]
image_sample_feed = images_test_gray[index:index+1,:,:,:]
label_sample_feed = labels_test_onehot[index:index+1]

# %%
import matplotlib.pyplot as plt

# %%
img = image_sample.astype('int')
plt.imshow(img, cmap="gray")
plt.show()
label_name = ['airplane', 'bird', 'car', 'cat', 'deer', 'dog', 'horse', 'monkey', 'ship', 'truck']
index_of_real = label_sample.argmax()
print('This is', label_name[index_of_real])
# Out:
# This is airplane

# %%
training = graph.get_tensor_by_name("Placeholder:0")

# %%
f, p, corr, logits= sess.run([xs, pred, correct, ys], feed_dict={X:image_sample_feed, Y:label_sample_feed, training:False})
index_of_prediction = p[0]
print(index_of_prediction, index_of_real)
print('Prediction:',label_name[index_of_prediction])
print('Correct:', corr[0])
G_real, G_pred = sess.run([grads[index_of_real], grads[index_of_prediction+1]], feed_dict={X:image_sample_feed, training:False})
G = G_pred[0]
# Out:
# 6 6
# Prediction: horse
# Correct: True

# %%
alpha = G.mean(axis=(0,1,2))

# %%
f.shape, alpha.shape
# Out:
# ((1, 16, 16, 128), (128,))

# %%
L = f * alpha

# %%
print(L.shape)
print(L.max(), L.min())
d = L.max() - L.min()
# Out:
# (1, 16, 16, 128)
# 0.03853959 -0.047190417

# %%
L_grad_cam = L.sum(axis=(0,3))
print(L_grad_cam.shape)
# Out:
# (16, 16)

# %%
import numpy as np
L_grad_cam = np.maximum(L_grad_cam, 0)

# %%
L_grad_cam = L_grad_cam / d * 255

# %%
L_grad_cam = L_grad_cam.astype('int')

# %%
L_grad_cam.shape
# Out:
# (16, 16)

# %%
plt.imshow(-L_grad_cam, cmap="Spectral")

# %%
plt.imshow(np.vstack([np.zeros((100,100), dtype='int'),np.zeros((100,100), dtype='int')+255]), cmap='Spectral')
